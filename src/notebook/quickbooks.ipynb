# %%
from intuitlib.client import AuthClient
from quickbooks import QuickBooks
from quickbooks.objects.account import Account
import pandas as pd
from matplotlib import pyplot as plt
plt.style.use('seaborn')
import numpy as np
import calendar

# %%
def proc_rows(rows, category = "", level=0):
    row_list = []
    for row in rows:
        if "Header" in row:
            header_col = row['Header']['ColData'][0]['value']
            if category == "":
                current_category = header_col
            else:
                current_category = f"{category}:{header_col}"
            row_list.extend(proc_rows(row['Rows']['Row'], category = current_category, level = level+1))
        else:
            col_data = row['ColData']
            if len(col_data)==len(cols):
                cur_row = {cols[i]:col_data[i]['value'] for i in range(len(cols))}
                cur_row.update({"category":category})
                cur_row.update({"category_level":level})
                row_list.append(cur_row)
    return row_list

# %%
auth_client = AuthClient(
        client_id='ABVlDV6VbSq3SyfN6ShES7gauQ8LExHxnhuoDVsKaEOe3GmBrT',
        client_secret='zqQX950hO9CICCreDvfAvk3mE7tuJJKrGyyrRxEU',
        access_token=None,
        environment='production',
        redirect_uri='https://developer.intuit.com/v2/OAuth2Playground/RedirectUrl',
    )

# %%
client = QuickBooks(
        auth_client=auth_client,
        refresh_token='AB117023062162rDFvIRMU11FsBJCY5GVFQS1niofojKma7HAx',
        company_id='514655250',
    )

# %%
# Date information
year = 2023
month = 7 # month number (i.e. 4 for April)
days = calendar.monthrange(year,month)[1]
month_name = calendar.month_name[month]

# %%
days = calendar.monthrange(year,month)[1]
month_name = calendar.month_name[month]
print(f"Grabbing report details for {month_name}")
json_resp = client.get_report("ProfitAndLossDetail", {"start_date":f"{year}-{month}-01", "end_date":f"{year}-{month}-{days}"})
cols = [i["ColTitle"] for i in json_resp['Columns']['Column']]
report_info = json_resp['Header']
row_list = proc_rows(json_resp["Rows"]["Row"][0]['Rows']['Row'])
# Out:
# Grabbing report details for July

# %%
# data manipulation
qbdf = pd.DataFrame(row_list)
qbdf['item'] = qbdf['category'].apply(lambda x: x.split(':')[-1])
qbdf['Amount'] = qbdf['Amount'].astype(float)

budget_map = "../resources/qb_to_budget_map.csv"
budgetdf = pd.read_csv(budget_map)
budget_items = budgetdf['QB_Item'].unique()

expense_types = ["Check","Expense"]
expenses = qbdf.loc[qbdf['Transaction Type'].astype(str).isin(expense_types)]
income = qbdf.loc[qbdf['Transaction Type'] == 'Deposit']

# check for unrecognized types and categories
types = qbdf["Transaction Type"].unique()
expected_types = ['Check','Expense','Deposit']
for t in types:
    if t not in expected_types:
        print(f"Warning: {t} not a recognized type")

for item in expenses['item'].unique():
    if item not in budget_items:
        print(f"Warning: {item} not in any budget category")
# Out:
# Warning: Worship Contribution not in any budget category

# %%
item_totals = expenses.groupby('item').aggregate({"Amount":"sum","Date":'count'}).reset_index()
item_totals.columns = ['item','Amount','Transactions']
all_totals = pd.merge(budgetdf,item_totals, left_on='QB_Item', right_on="item", how = 'left')
subcategory_totals = all_totals.groupby("Subcategory").aggregate({"Budget":"sum","Amount":"sum"}).reset_index()

# %%
total_expense = expenses['Amount'].sum()
total_income = income['Amount'].sum()
net_profit = total_income - total_expense

# %%
fig, ax = plt.subplots(figsize = (10,6))
ind = np.arange(len(subcategory_totals))
width = 0.45
budget = ax.bar(ind, subcategory_totals['Budget'], width, label = "Budget")
actual = ax.bar(ind+width, subcategory_totals["Amount"], width, label="Actuals")
ax.set_ylabel("Monthly Expenses")
ax.set_title(month_name, fontsize=20)
midx = ind.mean()
midy = max([subcategory_totals['Budget'].max(), subcategory_totals["Amount"].max()])*0.8
color = 'green'
if net_profit>0:
    color = 'green'
else:
    color = 'red'
ax.text(midx-1, midy, 'Income: {:.2f}\nExpenses: {:.2f}\nNet Profit: {:.2f}'.format(total_income,total_expense, net_profit), fontsize=14, bbox=dict(facecolor=color, alpha=0.5))
ax.legend()

ax.set_xticks(ind+width/2, subcategory_totals['Subcategory'], rotation=90, fontsize=15)
plt.tight_layout()
plt.savefig(f'{month_name}.png')

# %%
report_totals = all_totals[~all_totals['item'].isin(['Lead Pastor','Associate Pastor'])].sort_values(['Amount'], ascending=False).head(10)[['Item', 'Budget', 'Amount', 'Transactions']]
report_totals['Transactions'] = report_totals['Transactions'].astype(int)

# %%
report_totals
# Out:
#                  Item  Budget  Amount  Transactions
# 13          Utilities  462.50  629.17             1
# 16  Lawn/Snow Service  125.00  396.28             5
# 36       Life Network  129.00  377.00             1
# 37         Joel Frees  129.00  377.00             1
# 38          Crossfire  129.00  377.00             1
# 15   Cleaning Service  217.00  300.00             1
# 5      Communications   81.25  162.46             2
# 4           Equipment   42.00  162.29             1
# 24            Worship   83.00  116.58             3
# 33    Church Outreach   42.00  112.95             1

# %%
all_totals.sort_values("Amount", ascending=False)
# Out:
#       Category               Subcategory                             Item  \
# 0     Salaries                  Salaries                      Lead Pastor
# 1     Salaries                  Salaries                 Associate Pastor
# 30    Ministry     Individual Ministries              Honorarium/Blessing
# 22    Ministry     Individual Ministries                 Pastoral Expense
# 13  Facilities         Professional Fees                        Utilities
# 16  Facilities         Professional Fees                Lawn/Snow Service
# 20  Facilities               Hospitality  Food for Events, Sunday Morning
# 27    Ministry     Individual Ministries                 Student Ministry
# 3   Facilities           Building/Office                  Office Supplies
# 21  Facilities  Software & Subscriptions         Software & Subscriptions
# 32    Ministry                 Resources                  Right Now Media
# 26    Ministry     Individual Ministries                        Childrens
# 2     Salaries                  Salaries                        Childrens
# 4   Facilities           Building/Office                        Equipment
# 5   Facilities           Building/Office                   Communications
# 6   Facilities           Building/Office               Update/Renovations
# 7   Facilities           Building/Office      Building Repair/Maintenance
# 8   Facilities           Building/Office                            Decor
# 9   Facilities           Building/Office                            Trash
# 10  Facilities           Building/Office                  ENT Deposit Box
# 11  Facilities           Building/Office                 Church Insurance
# 12  Facilities           Building/Office            Refunded Transactions
# 14  Facilities         Professional Fees              City Watershed Fees
# 15  Facilities         Professional Fees                 Cleaning Service
# 17  Facilities         Professional Fees                      Incorp Fees
# 18  Facilities         Professional Fees          Property Tax Exempt Fee
# 19  Facilities               Hospitality     Kitchen/Cleaning/Paper Goods
# 23    Ministry     Individual Ministries                 Ministry Network
# 24    Ministry     Individual Ministries                          Worship
# 25    Ministry     Individual Ministries                     Discipleship
# 28    Ministry     Individual Ministries                        Communion
# 29    Ministry     Individual Ministries                     Coffee/Meals
# 31    Ministry     Marketing/Promotional            Marketing/Promotional
# 33    Ministry           Outreach/Events                  Church Outreach
# 34    Ministry      Conferences/Retreats             Conferences/Retreats
# 35      Giving  Charitable Contributions         Benevolence/Needy Family
# 36      Giving  Charitable Contributions                     Life Network
# 37      Giving  Charitable Contributions                       Joel Frees
# 38      Giving  Charitable Contributions                        Crossfire
#
#                             QB_Item   Budget                            item  \
# 0                       Lead Pastor  1300.00                     Lead Pastor
# 1                  Associate Pastor   600.00                Associate Pastor
# 30              Honorarium/Blessing   250.00             Honorarium/Blessing
# 22                Pastoral Expenses    83.00               Pastoral Expenses
# 13                        Utilities   462.50                       Utilities
# 16                        Lawn/Snow   125.00                       Lawn/Snow
# 20   Food for Events/Sunday Morning    42.00  Food for Events/Sunday Morning
# 27                 Student Ministry    42.00                Student Ministry
# 3                   Office Supplies    42.00                 Office Supplies
# 21       Software and Subscriptions   156.00      Software and Subscriptions
# 32                  Right Now Media    60.00                 Right Now Media
# 26                       Children's    21.00                      Children's
# 2     Children's Church Coordinator     0.00                             NaN
# 4                         Equipment    42.00                             NaN
# 5                    Communications    81.25                             NaN
# 6               Updates/Renovations    83.00                             NaN
# 7            Repair and Maintenance  1000.00                             NaN
# 8                             Decor    25.00                             NaN
# 9                             Trash    23.00                             NaN
# 10                      ENT Deposit     1.25                             NaN
# 11                 Church Insurance   377.50                             NaN
# 12            Refunded Transactions     0.00                             NaN
# 14              City Watershed Fees    21.07                             NaN
# 15                 Cleaning Service   217.00                             NaN
# 17               Incorporation Fees     0.84                             NaN
# 18          Property Tax Exempt Fee    12.50                             NaN
# 19  Kitchen/Cleaning/Paper Supplies    58.00                             NaN
# 23                 Ministry Network   165.00                             NaN
# 24                 Worship Expenses    83.00                             NaN
# 25                     Discipleship    12.50                             NaN
# 28                        Communion    25.00                             NaN
# 29                     Coffee/Meals    83.00                             NaN
# 31            Marketing/Promotional    42.00                             NaN
# 33                  Church Outreach    42.00                             NaN
# 34             Conferences/Retreats    83.00                             NaN
# 35                      Benevolence   129.00                             NaN
# 36                     Life Network   129.00                             NaN
# 37                       Joel Frees   129.00                             NaN
# 38                        Crossfire   129.00                             NaN
#
#      Amount
# 0   1200.00
# 1    750.00
# 30   500.00
# 22   350.45
# 13   302.72
# 16   300.00
# 20   158.26
# 27   106.73
# 3     84.43
# 21    77.23
# 32    59.99
# 26    37.31
# 2       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 14      NaN
# 15      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 28      NaN
# 29      NaN
# 31      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN

# %%
special_account = qbdf[qbdf['item']=='Worship Contribution']

# %%
fig, ax = plt.subplots()
ax.plot(special_account['Date'],special_account['Balance'].astype(float))
ax.set_ylabel("Account")
ax.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
special_account[['Date'],]
# Out:
#           Date Transaction Type Num    Name          Memo/Description  \
# 13  2023-07-05          Deposit               Charitable contribution
# 14  2023-07-06          Expense      Amazon  New sound snake - Amazon
#
#                            Split   Amount  Balance  \
# 13  1002 ENT Checking (Keystone)  5000.00  5000.00
# 14  1002 ENT Checking (Keystone) -1297.32  3702.68
#
#                              category  category_level                  item
# 13  Income:Tithe:Worship Contribution               3  Worship Contribution
# 14  Income:Tithe:Worship Contribution               3  Worship Contribution

# %%
income['item'].unique()
# Out:
# array(['Interest Earned', 'Olive Tree (Tenant Lease)', 'General Tithe',
#        'Worship Contribution'], dtype=object)
